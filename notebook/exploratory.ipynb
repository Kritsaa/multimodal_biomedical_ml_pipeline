# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
os.getcwd()
# Out:
# 'C:\\Users\\paxxr\\multimodal_biomedical_ml_pipeline\\notebook'

# %%
image_folder = "C:\\Users\\paxxr\\multimodal_biomedical_ml_pipeline\data\images"
image_files = sorted(os.listdir(image_folder))

img = plt.imread(os.path.join(image_folder, image_files[0]))

plt.imshow(img, cmap="gray")
plt.title("Example Synthetic CT-like Image")
plt.axis("off")
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
print("Image shape:", img.shape)
print("Min intensity:", img.min())
print("Max intensity:", img.max())
print("Mean intensity:", img.mean())
# Out:
# Image shape: (128, 128, 4)
# Min intensity: 0.0
# Max intensity: 1.0
# Mean intensity: 0.31944275

# %%
gene_df = pd.read_csv("../data/tabular/gene_expression.csv")
gene_df.head()
# Out:
#      Gene_1    Gene_2    Gene_3    Gene_4    Gene_5    Gene_6    Gene_7  \
# 0  0.486330  0.109655  0.524420  0.305911  0.692889  0.243253  0.925236
# 1  0.206274  0.576338  0.669946  0.593183  0.238750  0.022149  0.456298
# 2  0.807689  0.134710  0.934016  0.917514  0.350375  0.666690  0.927907
# 3  0.300201  0.429530  0.716318  0.906314  0.431456  0.070694  0.381622
# 4  0.151843  0.510451  0.671223  0.034473  0.051629  0.595886  0.517144
#
#      Gene_8    Gene_9   Gene_10  ...  Gene_491  Gene_492  Gene_493  Gene_494  \
# 0  0.280072  0.700740  0.949612  ...  0.899965  0.516630  0.496571  0.930972
# 1  0.775691  0.308470  0.436499  ...  0.354218  0.906080  0.801284  0.641895
# 2  0.091880  0.543010  0.702334  ...  0.891448  0.215965  0.907418  0.196884
# 3  0.889583  0.444952  0.552360  ...  0.759306  0.341392  0.843347  0.265988
# 4  0.741109  0.183330  0.755756  ...  0.573913  0.945111  0.205884  0.870065
#
#    Gene_495  Gene_496  Gene_497  Gene_498  Gene_499  Gene_500
# ...

# %%
gene_df.iloc[:, :20].boxplot(figsize=(10, 4))
plt.title("Distribution of Example Gene-like Features")
plt.xticks(rotation=90)
plt.tight_layout()
